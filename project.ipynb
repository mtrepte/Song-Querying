# %% [markdown]
# # 182 project
# songs

# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display
import numpy as np

# %%
x, sr = librosa.load('audio/sample.mp3')

# %%
plt.figure(figsize=(14, 5))
librosa.display.waveplot(x, sr=sr)

# %%
S = librosa.feature.melspectrogram(y=x[1000000:2000000], sr=sr)
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))

# %%
print(x[2000000])
# Out:
# 0.15349935
